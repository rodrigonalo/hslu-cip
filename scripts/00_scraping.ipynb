# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
def scrape_index_components_to_csv(url, csv_filename):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Create a list to hold all the company data
    companies_data = []

    # Extract the header names for columns
    headers = soup.select_one('table.table thead').find_all('th')
    columns = [header.get_text(strip=True) for header in headers]

    # Loop through the rows and extract data
    for row in soup.select('table.table tbody tr'):
        # Get all columns in the row
        cols = row.find_all('td')
        # Extract text and split on new lines or other appropriate separators
        col_text = [col.get_text(" ", strip=True) for col in cols]
        companies_data.append(col_text)

    # Create the DataFrame
    df = pd.DataFrame(companies_data, columns=columns)

    # Clean the DataFrame to remove rows with no company name
    df = df.dropna(subset=[columns[0]])  # assuming the first column is the company name

    # Save the DataFrame as CSV
    df.to_csv(f'../data/{csv_filename}', index=False)

    return df

# %% [markdown]
# ### AEX

# %%
url = "https://markets.businessinsider.com/index/components/aex"
csv_filename = 'aex_stock_data.csv'
df = scrape_index_components_to_csv(url, csv_filename)
print(df)
# Out:
#                          Name Latest PricePrevious Close    LowHigh  \
# 0                    ABN Amro                15.28 15.28  0.00 0.00
# 1   Adyen B.V. Parts Sociales          1,443.80 1,443.80  0.00 0.00
# 2              Ahold Delhaize                27.15 27.15  0.00 0.00
# 3                  Akzo Nobel                66.04 66.04  0.00 0.00
# 4               ArcelorMittal                24.37 24.37  0.00 0.00
# 5                     ASML NV              870.80 870.80  0.00 0.00
# 6           ASR Nederland N.V                42.54 42.54  0.00 0.00
# 7                    Heineken                84.28 84.28  0.00 0.00
# 8                        IMCD              159.60 159.60  0.00 0.00
# 9                   ING Group                14.29 14.29  0.00 0.00
# 10                        KPN                  3.33 3.33  0.00 0.00
# 11                   NN Group                40.91 40.91  0.00 0.00
# 12                    Philips                19.09 19.09  0.00 0.00
# 13                   Randstad                50.38 50.38  0.00 0.00
# 14                       RELX                39.73 39.73  0.00 0.00
# 15                      Shell                30.27 30.27  0.00 0.00
# 16             Wolters Kluwer              145.20 145.20  0.00 0.00
#
#              +/-%                                           TimeDate  \
# 0      0.09 0.56%  12:35 PM 03/19/2024 12:35:01 PM UTC-0400 18.03...
# 1   -13.20 -0.91%  12:35 PM 03/19/2024 12:35:12 PM UTC-0400 18.03...
# 2    -0.41 -1.47%  12:35 PM 03/19/2024 12:35:57 PM UTC-0400 18.03...
# 3      0.54 0.82%  12:35 PM 03/19/2024 12:35:15 PM UTC-0400 18.03...
# 4      0.16 0.64%  12:38 PM 03/19/2024 12:38:17 PM UTC-0400 18.03...
# 5     13.10 1.53%  12:36 PM 03/19/2024 12:36:01 PM UTC-0400 18.03...
# 6      0.14 0.33%  12:35 PM 03/19/2024 12:35:13 PM UTC-0400 18.03...
# 7    -1.12 -1.31%  12:36 PM 03/19/2024 12:36:18 PM UTC-0400 18.03...
# 8    -0.65 -0.41%  12:37 PM 03/19/2024 12:37:21 PM UTC-0400 18.03...
# 9      0.23 1.64%  12:35 PM 03/19/2024 12:35:22 PM UTC-0400 18.03...
# 10   -0.06 -1.89%  12:35 PM 03/19/2024 12:35:15 PM UTC-0400 18.03...
# 11     0.05 0.12%  12:35 PM 03/19/2024 12:35:28 PM UTC-0400 18.03...
# 12   -0.25 -1.31%  12:35 PM 03/19/2024 12:35:30 PM UTC-0400 18.03...
# 13   -0.02 -0.04%  12:37 PM 03/19/2024 12:37:26 PM UTC-0400 18.03...
# 14     0.24 0.61%  12:35 PM 03/19/2024 12:35:13 PM UTC-0400 18.03...
# 15     0.16 0.53%  12:38 PM 03/19/2024 12:38:26 PM UTC-0400 18.03...
# 16     0.65 0.45%  12:35 PM 03/19/2024 12:35:00 PM UTC-0400 18.03...
#
#         3 Mo.+/-%       6 Mo.+/-%     1 Year+/-%
# 0     1.58 11.62%      0.00 0.00%     1.12 7.97%
# 1   254.00 21.24%  732.10 101.98%    74.40 5.41%
# 2      1.52 5.79%    -1.42 -4.86%   -2.28 -7.61%
# 3    -7.40 -9.95%      0.00 0.00%   -0.28 -0.42%
# 4    -0.51 -2.04%      0.09 0.39%   -0.61 -2.41%
# 5   186.30 26.82%   319.20 56.82%  313.00 55.11%
# 6    -1.51 -3.50%      0.00 0.00%    5.31 14.63%
# 7    -3.88 -4.29%      0.00 0.00%   -8.40 -8.84%
# 8      1.15 0.75%      0.00 0.00%     8.65 5.94%
# 9      0.26 1.89%      0.98 7.53%    3.22 29.89%
# 10    0.32 10.36%      0.00 0.00%     0.22 6.88%
# 11    5.68 15.97%      0.00 0.00%    7.90 23.70%
# 12   -0.48 -2.36%  -11.29 -38.79%    5.44 37.73%
# 13  -6.62 -11.69%      0.00 0.00%  -7.98 -13.76%
# 14    5.54 15.86%      0.00 0.00%   11.89 41.62%
# 15     0.25 0.85%      0.00 0.00%    3.47 13.18%
# 16   14.10 10.84%      0.00 0.00%   31.05 27.44%

# %% [markdown]
# ### BEL 20

# %%
url = "https://markets.businessinsider.com/index/components/bel_20"
csv_filename = 'bel_20_stock_data.csv'
df = scrape_index_components_to_csv(url, csv_filename)
print(df)
# Out:
#                                      Name Latest PricePrevious Close  \
# 0   AB InBev SA-NV (Anheuser-Busch InBev)                55.19 55.15
# 1             Ackermans & van Haaren S.A.              156.70 156.50
# 2                                ageas NV                40.22 39.90
# 3                  Ahold Delhaize (Ahold)                27.04 27.22
# 4                          Cofinimmo S.A.                56.90 57.60
# 5                            D'Ieteren NV              197.20 197.50
# 6              Elia System Operator SA-NV                95.75 97.00
# 7                     Engie (ex GDF Suez)                15.39 15.30
# 8        Etablissementen Franz Colruyt NV                42.40 43.23
# 9     Groupe Bruxelles Lambert S.A. (GBL)                68.32 69.02
# 10                         KBC Groep N.V.                68.30 69.08
# 11                          NV Bekaert SA                47.76 47.86
# 12                 Proximus (ex Belgacom)                  7.36 7.63
# 13                            Solvay S.A.                23.32 23.20
# 14             Telenet Group Holding N.V.                  0.00 0.00
# 15                       ThromboGenics NV                  0.00 0.00
# 16                               UCB S.A.              107.35 105.90
#
#           LowHigh          +/-%  \
# 0     54.94 55.19    0.04 0.07%
# 1   156.70 156.70    0.20 0.13%
# 2     39.96 40.22    0.32 0.80%
# 3     27.04 27.04  -0.18 -0.64%
# 4     56.90 56.90  -0.70 -1.22%
# 5   197.20 197.20  -0.30 -0.15%
# 6     95.75 95.75  -1.25 -1.29%
# 7     15.25 15.40    0.08 0.55%
# 8     42.40 42.40  -0.83 -1.92%
# 9     68.32 68.32  -0.70 -1.01%
# 10    68.30 68.30  -0.78 -1.13%
csv'
df = scrape_index_components_to_csv(url, csv_filename)
print(df)
# Out:
#                                     Name Latest PricePrevious Close  \
# 0                     Aker Solutions ASA                  3.17 3.16
# 1                             BW LPG Ltd                10.48 10.60
# 2             Det Norske Oljeselskap ASA                23.31 23.21
# 3              DNO International ASA (A)                  0.79 0.81
# 4                                Equinor                24.50 24.55
# 5              Gjensidige Forsikring ASA                14.30 14.61
# 6                                   Mowi                17.38 17.08
# 7               Nordic Semiconductor ASA                  7.24 7.31
# 8                        Norsk Hydro ASA                  5.00 5.00
# 9                  Norwegian Air Shuttle                  1.41 1.42
# 10                              Orkla AS                  6.49 6.50
# 11                Otello Corporation ASA                  0.68 0.64
# 12            Petroleum Geo-Services ASA                  0.62 0.61
# 13                       REC Silicon ASA                  0.82 0.81
# 14          Royal Caribbean Cruises Ltd.              118.50 119.80
# 15                         Schibsted ASA                28.36 28.41
# 16                     Storebrand AsaShs                  8.41 8.54
# 17                         Subsea 7 S.A.                14.74 14.55
# 18                           Telenor ASA                10.19 10.15
# 19  TGS-Nopec Geophysical Company ASAShs                  9.48 9.45
# 20                Yara International ASA                29.30 29.13
#
#           LowHigh          +/-%  \
# 0       3.17 3.17    0.01 0.44%
# 1     10.35 10.49  -0.12 -1.13%
# 2     23.04 23.31    0.10 0.43%
# 3       0.79 0.79  -0.02 -2.04%
# 4     24.17 24.53  -0.05 -0.20%
# 5     14.30 14.30  -0.31 -2.12%
# 6     16.92 17.38    0.30 1.73%
# 7       7.23 7.24  -0.07 -1.01%
# 8       5.00 5.02    0.00 0.00%
# 9       1.41 1.45  -0.01 -0.95%
# 10      6.49 6.49  -0.01 -0.18%
# 11      0.68 0.68    0.04 6.23%
# 12      0.62 0.62    0.01 1.40%
# 13      0.82 0.82    0.01 1.28%
# 14  117.55 118.50  -1.30 -1.09%
# 15    28.36 28.36  -0.05 -0.18%
# 16      8.41 8.41  -0.13 -1.52%
# 17    14.74 14.74    0.20 1.34%
# 18    10.10 10.19    0.04 0.39%
# 19      9.48 9.48    0.04 0.37%
# 20    28.97 29.39    0.17 0.58%
#
#                                              TimeDate      3 Mo.+/-%  \
# 0   03:08 AM 03/19/2024 03:08:19 AM UTC-0400 19.03...   -0.34 -9.77%
# 1   12:15 PM 03/19/2024 12:15:01 PM UTC-0400 19.03...  -1.43 -11.17%
# 2   08:40 AM 03/19/2024 08:40:02 AM UTC-0400 19.03...  -2.88 -11.04%
# 3   03:08 AM 03/19/2024 03:08:20 AM UTC-0400 19.03...   -0.03 -3.03%
# 4   12:12 PM 03/19/2024 12:12:33 PM UTC-0400 19.03...  -4.84 -16.84%
# 5   03:22 AM 03/19/2024 03:22:47 AM UTC-0400 19.03...   -1.20 -7.44%
# 6   12:28 PM 03/19/2024 12:28:06 PM UTC-0400 19.03...     1.44 9.04%
# 7   05:24 AM 03/19/2024 05:24:09 AM UTC-0400 19.03...  -2.99 -28.55%
# 8   09:07 AM 03/19/2024 09:07:00 AM UTC-0400 19.03...  -0.81 -13.87%
# 9   02:29 PM 03/19/2024 02:29:17 PM UTC-0400 19.03...    0.50 50.00%
# 10  03:22 AM 03/19/2024 03:22:47 AM UTC-0400 19.03...   -0.12 -1.69%
# 11  03:22 AM 03/19/2024 03:22:47 AM UTC-0400 19.03...   -0.01 -1.16%
# 12  03:08 AM 03/19/2024 03:08:20 AM UTC-0400 19.03...  -0.16 -22.84%
# 13  03:22 AM 03/19/2024 03:22:47 AM UTC-0400 19.03...  -0.17 -15.12%
# 14  11:52 AM 03/19/2024 11:52:15 AM UTC-0400 19.03...     6.29 5.13%
# 15  03:08 AM 03/19/2024 03:08:20 AM UTC-0400 19.03...     0.03 0.11%
# 16  03:08 AM 03/19/2024 03:08:20 AM UTC-0400 19.03...    0.91 11.69%
# 17  03:08 AM 03/19/2024 03:08:20 AM UTC-0400 19.03...    1.36 10.67%
# 18  08:08 AM 03/19/2024 08:08:59 AM UTC-0400 19.03...   -0.41 -3.96%
# 19  03:08 AM 03/19/2024 03:08:20 AM UTC-0400 19.03...  -1.61 -14.69%
# 20  07:10 AM 03/19/2024 07:10:40 AM UTC-0400 19.03...   -2.81 -8.85%
#
#        6 Mo.+/-%      1 Year+/-%
# 0     0.00 0.00%   -0.45 -12.42%
# 1     0.00 0.00%     4.08 55.86%
# 2     0.00 0.00%    -0.33 -1.40%
# 3     0.00 0.00%   -0.14 -14.85%
# 4     0.00 0.00%    -2.18 -8.35%
# 5     0.00 0.00%    -0.88 -5.57%
# 6     0.00 0.00%      1.55 9.84%
# 7     0.00 0.00%   -7.02 -48.43%
# 8     0.00 0.00%   -1.35 -21.14%
# 9     0.00 0.00%     0.55 57.99%
# 10    0.00 0.00%      0.54 8.64%
# 11    0.00 0.00%    -0.01 -1.73%
# 12    0.00 0.00%   -0.43 -43.96%
# 13    0.00 0.00%   -0.58 -37.66%
# 14  31.38 32.19%    63.99 98.63%
# 15    0.00 0.00%     8.59 46.26%
# 16    0.00 0.00%     1.71 24.29%
# 17    0.00 0.00%     3.11 28.40%
# 18    0.00 0.00%    -0.56 -5.28%
# 19    0.00 0.00%   -7.66 -45.03%
# 20    0.00 0.00%  -11.38 -28.22%

# %% [markdown]
# ### PSI

# %%
url = "https://markets.businessinsider.com/index/components/psi"
csv_filename = 'psi_stock_data.csv'
df = scrape_index_components_to_csv(url, csv_filename)
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 3
#       1 url = "https://markets.businessinsider.com/index/components/psi"
#       2 csv_filename = 'psi_stock_data.csv'
# ----> 3 df = scrape_index_components_to_csv(url, csv_filename)
#       4 print(df)
#
# Cell In[17], line 9, in scrape_index_components_to_csv(url, csv_filename)
#       6 companies_data = []
#       8 # Extract the header names for columns
# ----> 9 headers = soup.select_one('table.table thead').find_all('th')
#      10 columns = [header.get_text(strip=True) for header in headers]
#      12 # Loop through the rows and extract data
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# ### OSEBX BENCHMARK

# %%
url = "https://markets.businessinsider.com/index/components/osebx_benchmark"
csv_filename = 'osebx_benchmark_stock_data.csv'
df = scrape_index_components_to_csv(url, csv_filename)
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 3
#       1 url = "https://markets.businessinsider.com/index/components/osebx_benchmark"
#       2 csv_filename = 'osebx_benchmark_stock_data.csv'
# ----> 3 df = scrape_index_components_to_csv(url, csv_filename)
#       4 print(df)
#
# Cell In[17], line 9, in scrape_index_components_to_csv(url, csv_filename)
#       6 companies_data = []
#       8 # Extract the header names for columns
# ----> 9 headers = soup.select_one('table.table thead').find_all('th')
#      10 columns = [header.get_text(strip=True) for header in headers]
#      12 # Loop through the rows and extract data
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %% [markdown]
# ### CAC 40

# %%
url = "https://markets.businessinsider.com/index/components/cac_40"
csv_filename = 'cac_40_stock_data.csv'
df = scrape_index_components_to_csv(url, csv_filename)
print(df)
# Out:
#
# 11    22.96 12.39%    32.88 18.75%     50.75 32.23%
# 12    -1.80 -3.10%      0.84 1.52%     -3.98 -6.61%
# 13   369.00 18.24%   488.90 25.68%    706.50 41.90%
# 14      8.35 2.00%   -42.90 -9.15%  -113.10 -20.97%
# 15      0.74 0.76%     9.26 10.48%     13.72 16.35%
# 16      4.70 1.05%    41.25 10.06%     80.10 21.58%
# 17   124.40 16.62%   111.60 14.66%     98.10 12.66%
# 18      2.19 6.79%     4.18 13.81%      7.36 27.15%
# 19    -0.13 -1.23%    -0.63 -5.70%     -0.31 -2.90%
# 20   -10.60 -6.50%  -19.45 -11.31%   -46.10 -23.22%
# 21    15.04 18.03%    25.06 34.15%     27.32 38.41%
# 22      3.17 8.06%     4.29 11.26%      5.79 15.78%
# 23    40.24 25.12%    47.98 31.48%     73.26 57.62%
# 24      2.54 3.81%    11.91 20.81%     17.88 34.87%
# 25      0.51 0.58%  -14.59 -14.19%     -1.56 -1.74%
# 26    34.01 18.78%    57.71 36.66%     70.65 48.89%
# 27    -0.96 -3.91%   -3.00 -11.33%       1.98 9.19%
# 28  -36.17 -29.49%  -38.52 -30.82%  -136.72 -61.25%
# 29     3.83 17.79%     7.48 41.85%      9.58 60.69%
# 30    -3.94 -8.41%      1.54 3.73%     -1.25 -2.82%
# 31      1.08 1.75%      0.34 0.55%      9.44 17.72%
# 32      4.70 7.07%    24.00 50.85%     17.99 33.81%
# 33    -0.62 -2.09%    -0.46 -1.56%       2.36 8.82%
# 34      1.42 1.23%      9.52 8.86%     14.60 14.26%
# 35      0.43 4.48%     1.81 22.02%      1.04 11.57%

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def scrape_index_components_to_csv(url, csv_filename):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Create a list to hold all the company data
    companies_data = []

    # Extract the header names for columns
    headers = soup.select_one('table.table thead').find_all('th')
    columns = [header.get_text(strip=True) for header in headers]

    # Loop through the rows and extract data
    for row in soup.select('table.table tbody tr'):
        # Get all columns in the row
        cols = row.find_all('td')
        # Extract text and split on new lines or other appropriate separators
        col_text = [col.get_text(" ", strip=True) for col in cols]
        companies_data.append(col_text)

    # Create the DataFrame
    df = pd.DataFrame(companies_data, columns=columns)

    # Clean the DataFrame to remove rows with no company name
    df = df.dropna(subset=[columns[0]])  # assuming the first column is the company name

    # Save the DataFrame as CSV
    df.to_csv(csv_filename, index=False)

    return df

# Example usage:
url = "https://markets.businessinsider.com/index/components/aex"
csv_filename = '1_stock_data.csv'
df = scrape_index_components_to_csv(url, csv_filename)
print(df)
# Out:
#                          Name Latest PricePrevious Close    LowHigh  \
# 0                    ABN Amro                15.28 15.28  0.00 0.00
# 1   Adyen B.V. Parts Sociales          1,443.80 1,443.80  0.00 0.00
# 2              Ahold Delhaize                27.15 27.15  0.00 0.00
# 3                  Akzo Nobel                66.04 66.04  0.00 0.00
# 4               ArcelorMittal                24.37 24.37  0.00 0.00
# 5                     ASML NV              870.80 870.80  0.00 0.00
# 6           ASR Nederland N.V                42.54 42.54  0.00 0.00
# 7                    Heineken                84.28 84.28  0.00 0.00
# 8                        IMCD              159.60 159.60  0.00 0.00
# 9                   ING Group                14.29 14.29  0.00 0.00
# 10                        KPN                  3.33 3.33  0.00 0.00
